# %% [markdown]
# # Task-01
#
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution
# of ages or genders in a population.
#
# DataSet:world_population_data.csv

# %%
# import necessary liberaies

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('world_population_data.csv')

# %%
df
# Out:
#      Unnamed: 0  Rank           country country_code         1980        2000  \
# 0             0     1             China          CHN  982372466.0  1264099069
# 1             1     2             India          IND  696828385.0  1059633675
# 2             2     3     United States          USA  223140018.0   282398554
# 3             3     4         Indonesia          IDN  148177096.0   214072421
# 4             4     5          Pakistan          PAK   80624057.0   154369924
# ..          ...   ...               ...          ...          ...         ...
# 229         229   230        Montserrat          MSR      11452.0        5138
# 230         230   231  Falkland Islands          FLK       2240.0        3080
# 231         231   232              Niue          NIU       3637.0        2074
# 232         232   233           Tokelau          TKL       1647.0        1666
# 233         233   234      Vatican City          VAT        733.0         651
#
# ...

# %%
df.head(7)
# Out:
#    Unnamed: 0  Rank        country country_code         1980        2000  \
# 0           0     1          China          CHN  982372466.0  1264099069
# 1           1     2          India          IND  696828385.0  1059633675
# 2           2     3  United States          USA  223140018.0   282398554
# 3           3     4      Indonesia          IDN  148177096.0   214072421
# 4           4     5       Pakistan          PAK   80624057.0   154369924
# 5           5     6        Nigeria          NGA   72951439.0   122851984
# 6           6     7         Brazil          BRA  122288383.0   175873720
#
#          2010        2021        2022        2030        2050       area  \
# 0  1348191368  1425893465  1425887337  1415605906  1312636325  9706961.0
# 1  1240613620  1407563842  1417173173  1514994080  1670490596  3287590.0
# 2   311182845   336997624   338289857   352162301   375391963  9372610.0
# 3   244016173   273753191   275501339   292150100   317225213  1904569.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Rank               0
# country            0
# country_code       0
# 1980               0
# 2000               0
# 2010               0
# 2021               0
# 2022               0
# 2030               0
# 2050               0
# area               0
# landAreaKm         0
# growthRate         0
# worldPercentage    0
# density            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
x="density"
y="area"
#c=['r','y','g','b']
plt.scatter(x, y,data=df,)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you want to create a histogram for the 'country_code' variable
#c=['r','y','g','b']
sns.histplot(df['growthRate'])

# Customize the plot
plt.title('Histogram of growthRate')
plt.xlabel('growthRate')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you want to create a histogram for the 'country_code' variable
sns.barplot(df['growthRate'] ,color="skyblue",edgecolor="black")

# Customize the plot
plt.title('bar of growthRate')
plt.xlabel('growthRate')
# Show the plot
plt.show()

# %%
x="growthRate"
y="area"
sns.lineplot(data=df, x="growthRate", y="area")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Bar color demo

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

growthRate = ['0.0000', '0.0068', '0.0038', '0.0064']
density = [  151.2926, 476.6507, 36.9820, 146.7369]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(growthRate, density, label=bar_labels, color=bar_colors)

ax.set_ylabel('growthRate')
ax.set_title('growthRate by kind and color')
ax.legend(title='color')

plt.show()
